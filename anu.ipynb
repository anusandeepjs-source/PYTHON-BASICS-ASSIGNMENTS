# %%
1
name = "PYTHON"
age = 2  
height = 1.50
weight = 40
print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Weight:", weight)
# Out:
# Name: PYTHON
# Age: 2
# Height: 1.5
# Weight: 40

# %%
2
a = 3+ 3j

print("Complex number:", a)
print("Real part:",a.real)
print("Imaginary part:",a.imag)
# Out:
# Complex number: (3+3j)
# Real part: 3.0
# Imaginary part: 3.0

# %%
3
a = 45
b = 3.5
c = True
d = "Python"
e = 3 + 2j
f = None


print("Type of", a, "is", type(a))
print("Type of", b, "is", type(b))
print("Type of", c, "is", type(c))
print("Type of", d, "is", type(d))
print("Type of", e, "is", type(e))
print("Type of", f, "is", type(f))
# Out:
# Type of 45 is <class 'int'>
# Type of 3.5 is <class 'float'>
# Type of True is <class 'bool'>
# Type of Python is <class 'str'>
# Type of (3+2j) is <class 'complex'>
# Type of None is <class 'NoneType'>

# %%
4
num = 1.10
num_int = int(num)
num_str = str(num)
print("Original float:", num, ",Type:", type(num))
print("Converted to int:", num_int, ", Type:", type(num_int))
print("Converted to string:", num_str, ", Type:", type(num_str))
# Out:
# Original float: 1.1 ,Type: <class 'float'>
# Converted to int: 1 , Type: <class 'int'>
# Converted to string: 1.1 , Type: <class 'str'>

# %%
5
a= 5
b = 10
a, b = b, a
print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# After swapping:
# a = 10
# b = 5

# %%
6
age = 20
print("Age:", age)
print("Is 'age' of type int?", type(age) == int)
# Out:
# Age: 20
# Is 'age' of type int? True

# %%
7
num1 = 7      
num2 = 5.8
sum = num1 + num2
print("sum:", sum)
print("Type of sum:", type(sum))
# Out:
# sum: 12.8
# Type of sum: <class 'float'>

# %%
8
a = "hi"
result = a * 5
print(result)
# Out:
# hihihihihi

# %%
9
a = 1         
b = 1.5        
c = 2 + 3j 
total = a+b+c
print("Sum:", total)
print("Type of result:", type(total))
# Out:
# Sum: (4.5+3j)
# Type of result: <class 'complex'>

# %%
10
a = None
print("Value:",a)
print("Type:", type(a))
# Out:
# Value: None
# Type: <class 'NoneType'>

# %%
11
name = "Anu Mohan P"
print("Uppercase:",name.upper())
print("Lowercase:",name.lower())
print("Title Case:",name.title())
# Out:
# Uppercase: ANU MOHAN P
# Lowercase: anu mohan p
# Title Case: Anu Mohan P

# %%
12
input = "Python class"
length = len(input)
print("Length of string:", length)
# Out:
# Length of string: 12

# %%
13
a = "Anu"
b = "Mohan"
string =a + " " + b
print("Full name:", string)
# Out:
# Full name: Anu Mohan

# %%
14

a = "Anu Mohan"
first_name = a.split()[0]
print("First name:", first_name)
# Out:
# First name: Anu

# %%
15
a= "hi "
b = a * 3
print(b)
# Out:
# hi hi hi

# %%
16
a = "Python is cool"
count_o = a.count('o')
print("Number of times 'o' appears:", count_o)
# Out:
# Number of times 'o' appears: 3

# %%
17
a = "Datascience"
first = a[:4]
last = a[-4:]
middle = a[2:8] 
print("First 4 characters:", first)
print("Last 4 characters:", last)
print("Middle characters:", middle)
# Out:
# First 4 characters: Data
# Last 4 characters: ence
# Middle characters: tascie

# %%
18
reversed_string = "Python"[::-1]
print(reversed_string)
# Out:
# nohtyP

# %%
19
string = "Pythonprogram"[::2]
print(string)
# Out:
# Ptoporm

# %%
20
a = "Python"[2:]
print(a)
# Out:
# thon

# %%
21
string = "ArtificialIntelligence"[10:]
print(string)
# Out:
# Intelligence

# %%
22
string = "learnlogic"
last_three = string[-3:]
print(last_three)
# Out:
# gic

# %%
23
string = "pythoncode"
result = string[::-3]
print(result)
# Out:
# echp

# %%
24
input = "MachineLearning"
a= input[:7]
b =input[7:]

print(a)   
print(b)
# Out:
# Machine
# Learning

# %%
25
number = "123456789"
result = number[::2]
print(result)
# Out:
# 13579

# %%
26
input = "Python"
index = len(input) // 2
char = input[index]
print(char)
# Out:
# h

# %%
27
text = "I love Python"
new_text = text.replace("Python", "Java")
print(new_text)
# Out:
# I love Java

# %%
28
text = "Python"
result = text.startswith("Py")
print(result)
# Out:
# True

# %%
29
text = "Python is fun"
new_text = text.replace(" ", "")
print(new_text)
# Out:
# Pythonisfun

# %%
30
text = "Python"
text1 = text.find("on")
print(text1)
# Out:
# 4

# %%
31
text = "12345"
text1 = text.isnumeric()
print(text1)
# Out:
# True
